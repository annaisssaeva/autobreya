# %%
import requests
from pprint import pprint
# !pip3 install fake_useragent
from fake_useragent import UserAgent
from bs4 import BeautifulSoup

session = requests.session()
good_reviews = ''
ua = UserAgent()

# %%
url = f'https://irecommend.ru/content/igra-prestolov-game-thrones?page=1&ft[r]=1'
req = session.get(url, headers={'User-Agent': ua.random})
page = req.text
soup = BeautifulSoup(page, 'html.parser')
print(soup)

good_reviews = ''
n_odd = soup.find_all('ul', {"class":"list-comments"})[0].find_all('li', {'class':"item"})
count = 0
for article in n_odd:
    link = n_odd[n_odd.index(article)].find_all("a", {'class': 'more'})[0].attrs['href']
    new_link = "https://irecommend.ru"+link
    print(new_link)
    ua = UserAgent()
    req3 = session.get(new_link, headers={'User-Agent': ua.random})
    page3 = req3.text
    soup3 = BeautifulSoup(page3, 'html.parser')
    raw_text = soup3.find_all('div', {'class': 'description hasinlineimage'})
    if len(raw_text) >= 1:
        count += 1
        raw_text1 = raw_text[0].text
        good_reviews += raw_text1

with open("good2.txt", "w") as file:
    file.write(good_reviews)
print(count)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7 ]>		 <html class="no-js ie ie7 lte7 lte8 lte9" lang="ru"> <![endif]-->
# <!--[if IE 8 ]>		 <html class="no-js ie ie8 lte8 lte9" lang="ru"> <![endif]-->
# <!--[if IE 9 ]>		 <html class="no-js ie ie9 lte9>" lang="ru"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js ab8" lang="ru"> <!--<![endif]-->
# <head prefix="fb: http://ogp.me/ns/fb#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>Игра престолов / Game of Thrones | отзывы</title>
# <meta content="noindex" name="robots"/>
# <meta content="100001701105335" property="fb:admins"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1.0, user-scalable=no" id="metaviewport" name="viewport"/>
# <link as="font" crossorigin="anonymous" href="/themes/irecommend_new/media/icon-fonts/fontello.woff2?37885219" rel="preload" type="font/woff2"/>
# <style>body,button,input{font-family: "Open Sans", "Arial", sans-serif}</style>
# <script>
# ...
